# %%
"""
ANOVA 

Stands for analysis of variance
We do ANOVA test to check how each class is different from one another

Rules - 

There has to be altleast 3 or more classes



Test case - 

UN (United Nation) is doing a survey to check if the Schools in developed countries 
give the same quality of education

Like UK, USA, AUSTRALIA provide same quality education


1) Null hypothesis ->>>> UK, USA and AUSTRALIA gives sames quality of Education
2) Alternative hypothesis ->>>> UK, USA, and AUSTRALIA DOES NOT give the same quality of education


Rule is, you need to make sure that samples are randomly collected

So, we select 1 random school from each country and give a test of 10 marks to 3 students from each school

Now after test here are results 

USA  Aus  UK

3    5    5
2    3    6
1    4    7

First we take mean from each country

x1 = 2
x2 = 4
x3 = 6

Now we need to calculate the SST (Sum of Squared in Total)

Step 1 - 
First take the values of each country and divide that by count of each class
(Sum of whole mean) 

X = (3+2+1) + (5+3+4) + (5+6+7)
    ---------------------------
        3   +    3   +     3
        
  = 6 + 12 + 18
    -----------
        9
        
  = 36/9
  =  4
  
Step 2 - 
Sum of all (x - marks of each student in each country) minus the mean (X)^2 

SST = (3-4)^2 + (2-4)^2 + (1-4)^2 + (5-4)^2 + (3-4)^2 + (4-4)^2 + (5-4)^2 + (6-4)^2 + (7-4)^2
    
    = 30
    
Now we have SST, we need to calculate SSB-(sum of squares within the bracket) and SSW-(Sum of squares between the brackets)
    

Step 3 - Calculate SSW

Subract each indicidual marks by the mean of its class

SSW = (3-2)^2 + (2-2)^2 + (1-2)^2 + (5-4)^2 + (3-4)^2 + (4-4)^2 + (5-6)^2 + (6-6)^2 + (7-6)^2

    = 1 + 0 + 1 + 1 + 1 + 0 + 1 + 0 + 2
    
    = 2 + 2 + 2
    
    = 6
    

Step 4 - calcualte SSB
Take the whole mean (4) and subract each class mean from it

SSB = (2-4)^2 + (2-4)^2 + (2-4)^2 + (4-4)^2 + (4-4)^4 + (4-4)^2 + (6-4)^2 + (6-4)^2 + (6-4)^2

    = 4 + 4 + 4 + 0 + 0 + 0 + 4 + 4 + 4
    
    = 24
    
    
Step 5 - 

SST = 30 (SSW + SSB)

SSW = 6
SSB = 24

Out of total 30 (SST) only 6 (SSW) comes from WITHIN the bracket and rest 24 (SSB) comes from BETWEEN the bracket

Rules to follow 

a) If most of the variance comes from BETWEEN the group then there is a significant effect and 
we should Reject the null hypothesis 

b) If most of the variance comes from WITHIN the group then there is not a significant effect and 
we should either change the samples or accept the null hypothesis

Conclusion

Since SSB is greater - we can reject the null hypothesis and conclude that since the marks of each country vary 
significantly, its not possible that they provide the same quality of education


"""
